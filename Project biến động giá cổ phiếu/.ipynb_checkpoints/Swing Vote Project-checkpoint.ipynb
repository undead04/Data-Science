# %% [markdown]
# # Project Swing Vote
# ## 1. Import thử viện

# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score #đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error #đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error #đo % sai số tuyệt đối trung bình

# %% [markdown]
# ## 2. Đọc dữ liệu

# %%
# Danh sách các file cổ phiếu
stock_files = [
    "./data/fpt.csv",
    "./data/msn.csv",
    "./data/pnj.csv",
    "./data/vic.csv",
]

# Tạo dictionary để lưu trữ dữ liệu của từng cổ phiếu
stock_data = {}

for file in stock_files:
    # Đọc file và lưu vào dictionary
    stock_name = file.split("/")[-1].replace(".csv", "")  # Lấy tên cổ phiếu từ file
    stock_data[stock_name] = pd.read_csv(file)

# %%
stock_data['fpt'].head()
# Out:
#   Ticker        Date/Time   Open   High    Low  Close  Volume  Open Interest
# 0    FPT  12/25/2018 9:15  30.89  30.89  30.89  30.89   35410              0
# 1    FPT  12/25/2018 9:16  30.81  30.81  30.81  30.81     190              0
# 2    FPT  12/25/2018 9:17  30.74  30.81  30.74  30.74    1120              0
# 3    FPT  12/25/2018 9:18  30.74  30.74  30.74  30.74    2120              0
# 4    FPT  12/25/2018 9:19  30.74  30.74  30.74  30.74   22500              0

# %% [markdown]
# ### Ghi chú
# - `Open`: Giá mở cửa trong phiên giao dịch
# - `High`: Giá cao nhất đạt được trong phiên giao dịch.
# - `Low`: Giá thấp nhất đạt được trong phiên giao dịch.
# - `Close`: Giá đóng cửa trong phiên giao dịch.
# - `Volume`: Khối lượng cổ phiếu được giao dịch.
# - `Open Interest`: Lượng hợp đồng phái sinh đang mở (có thể không áp dụng nếu bạn chỉ làm việc với cổ phiếu cơ sở, giá trị ở đây là 0).

# %% [markdown]
# ## 3. Mô tả dữ liêu

# %%
for stock_name in stock_data:
    stock_data[stock_name].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97406 entries, 0 to 97405
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ticker         97406 non-null  object
#  1   Date/Time      97406 non-null  object
#  2   Open           97406 non-null  float64
#  3   High           97406 non-null  float64
#  4   Low            97406 non-null  float64
#  5   Close          97406 non-null  float64
#  6   Volume         97406 non-null  int64
#  7   Open Interest  97406 non-null  int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 5.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135354 entries, 0 to 135353
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Ticker         135354 non-null  object
#  1   Date/Time      135354 non-null  object
#  2   Open           135354 non-null  float64
#  3   High           135354 non-null  float64
#  4   Low            135354 non-null  float64
#  5   Close          135354 non-null  float64
#  6   Volume         135354 non-null  int64
#  7   Open Interest  135354 non-null  int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 8.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125309 entries, 0 to 125308
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Ticker         125309 non-null  object
#  1   Date/Time      125309 non-null  object
#  2   Open           125309 non-null  float64
#  3   High           125309 non-null  float64
#  4   Low            125309 non-null  float64
#  5   Close          125309 non-null  float64
#  6   Volume         125309 non-null  int64
#  7   Open Interest  125309 non-null  int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 7.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101266 entries, 0 to 101265
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Ticker         101266 non-null  object
#  1   Date/Time      101266 non-null  object
#  2   Open           101266 non-null  float64
#  3   High           101266 non-null  float64
#  4   Low            101266 non-null  float64
#  5   Close          101266 non-null  float64
#  6   Volume         101266 non-null  int64
#  7   Open Interest  101266 non-null  int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 6.2+ MB

# %% [markdown]
# * Numerical:`Open`,`High`,`Low`,`Close`,`Volume`
# * Various Data Type:String,Int,Float

# %%
for stock_name in stock_data:
    print(stock_data[stock_name].shape)
# Out:
# (97406, 8)
# (135354, 8)
# (125309, 8)
# (101266, 8)

# %%
for stock_name in stock_data:
    print(stock_data[stock_name].describe())
# Out:
#                Open          High           Low         Close        Volume  \
# count  97406.000000  97406.000000  97406.000000  97406.000000  9.740600e+04
# mean      45.071630     45.090138     45.051430     45.071631  8.044173e+03
# std        6.359803      6.364950      6.354245      6.359799  1.753203e+04
# min       30.250000     30.250000     30.220000     30.250000  1.000000e+01
# 25%       39.740000     39.740000     39.700000     39.740000  7.500000e+02
# 50%       46.950000     46.950000     46.950000     46.950000  2.960000e+03
# 75%       49.200000     49.250000     49.170000     49.200000  8.960000e+03
# max       58.400000     58.500000     58.400000     58.400000  1.255930e+06
#
#        Open Interest
# count        97406.0
# mean             0.0
# std              0.0
# min              0.0
# 25%              0.0
# 50%              0.0
# 75%              0.0
# max              0.0
#                 Open           High            Low          Close  \
# count  135354.000000  135354.000000  135354.000000  135354.000000
# mean       74.878809      74.931668      74.834625      74.880759
# std        15.418074      15.426954      15.412677      15.418857
# min        46.500000      46.500000      46.400000      46.400000
# 25%        57.900000      57.900000      57.800000      57.800000
# 50%        79.100000      79.200000      79.100000      79.100000
# 75%        86.000000      86.100000      86.000000      86.000000
# max       117.800000     118.000000     117.700000     118.000000
#
#              Volume  Open Interest
# count  1.353540e+05       135354.0
# mean   5.683578e+03            0.0
# std    2.798513e+04            0.0
# min    1.000000e+01            0.0
# 25%    5.000000e+02            0.0
# 50%    2.000000e+03            0.0
# 75%    5.560000e+03            0.0
# max    3.300680e+06            0.0
#                 Open           High            Low          Close  \
# count  125309.000000  125309.000000  125309.000000  125309.000000
# mean       72.182052      72.372590      72.042287      72.179371
# std         9.900263       9.995786       9.830847       9.899401
# min        44.430000      44.530000      44.040000      44.140000
# 25%        64.600000      64.700000      64.570000      64.600000
# 50%        72.800000      73.010000      72.640000      72.830000
# 75%        80.160000      80.350000      80.060000      80.160000
# max       100.160000     100.160000     100.160000     100.160000
#
#               Volume  Open Interest
# count  125309.000000       125309.0
# mean     3031.830451            0.0
# std      7248.952968            0.0
# min         1.000000            0.0
# 25%       220.000000            0.0
# 50%      1000.000000            0.0
# 75%      3130.000000            0.0
# max    580730.000000            0.0
#                 Open           High            Low          Close  \
# count  101266.000000  101266.000000  101266.000000  101266.000000
# mean      105.376460     105.418519     105.334147     105.378791
# std        11.543158      11.535584      11.552338      11.545054
# min        68.000000      68.000000      68.000000      68.000000
# 25%        95.400000      95.400000      95.300000      95.400000
# 50%       105.300000     105.300000     105.200000     105.300000
# 75%       115.800000     115.900000     115.800000     115.800000
# max       126.100000     126.500000     126.100000     126.500000
#
#              Volume  Open Interest
# count  1.012660e+05       101266.0
# mean   3.182640e+03            0.0
# std    1.469814e+04            0.0
# min    1.000000e+01            0.0
# 25%    2.300000e+02            0.0
# 50%    1.020000e+03            0.0
# 75%    3.000000e+03            0.0
# max    1.468390e+06            0.0

# %% [markdown]
# ## 4. Tiền sữ lí dữ liệu

# %%
def preprocess_stock_data(df):
    # Tiền xử lý từng DataFrame
    df['Date/Time'] = pd.to_datetime(df['Date/Time'], format='%m/%d/%Y %H:%M')  # Chuyển đổi cột ngày
    df = df.sort_values(by='Date/Time')  # Sắp xếp theo ngày
    return df

# Tiền xử lý cho từng cổ phiếu
for stock_name in stock_data:
    stock_data[stock_name] = preprocess_stock_data(stock_data[stock_name])

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

def stock_chart(df,stock_name):
    # Lấy thông tin năm từ cột "Ngày"
    df['Year'] = df['Date/Time'].dt.year
    plt.figure(figsize=(10, 5))
    plt.xlabel('Năm')
    plt.ylabel('Giá đóng cửa')
    plt.title(f'Biểu đồ giá đóng cửa của cổ phiếu {str.upper(stock_name)} qua các năm')
    # Tạo đồ thị giá đóng cửa qua các năm
    plt.plot(df['Date/Time'], df['Close'], label=f'Giá đóng cửa - {str.upper(stock_name)}',color='blue')
    # Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
    years = YearLocator()
    yearsFmt = DateFormatter('%Y')
    months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
    plt.gca().xaxis.set_major_locator(years)
    plt.gca().xaxis.set_major_formatter(yearsFmt)
    plt.gca().xaxis.set_minor_locator(months)
    plt.legend(loc='best')
    plt.tight_layout();
for stock_name in stock_data: 
    stock_chart(stock_data[stock_name],stock_name)

# %%
scaler = MinMaxScaler()
scaled_data = {}
# Chuẩn hóa sữ liệu
def data_normalization(df):
    return scaler.fit_transform(df['Close'].values.reshape(-1, 1))
for stock_name in stock_data:
    scaled_data[stock_name] = data_normalization(stock_data[stock_name])

# %%
# Tạo tập dữ liệu cho LSTM
def create_dataset(data, time_step=50):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:i + time_step])
        y.append(data[i + time_step])
    return np.array(X), np.array(y)

X,y = {},{}
time_step = 50
for stock_name in stock_data:
    X[stock_name],y[stock_name] = create_dataset(scaled_data[stock_name],time_step)

# %%
# Chia train/test
def split_train_text(X,y):
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    return X_train,y_train,X_test,y_test

# Khao báo X_train,y_train
X_train,y_train,X_test,y_test = {},{},{},{}    
for stock_name in stock_data:
    X_train[stock_name],y_train[stock_name],X_test[stock_name],y_test[stock_name] = split_train_text(X[stock_name],y[stock_name])

# %% [markdown]
# ## Bước 5: Xây dựng và huấn luyện mô hình

# %%
from keras.layers import Input

model = {}

# Xây dựng mô hình 
def model_building(X_train):
    model = Sequential([
        Input(shape=(X_train.shape[1],1)),
        LSTM(128, return_sequences=True),
        Dropout(0.2),
        LSTM(64),
        Dropout(0.2),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

for stock_name in stock_data:
    model[stock_name] = model_building(X_train[stock_name])

# %%
#huấn luyện mô hình
from tensorflow.keras.callbacks import ModelCheckpoint

def model_training(stock_name,model,X_train,y_train):
    # Tạo callback để lưu mô hình tốt nhất
    checkpoint = ModelCheckpoint(
        f'best_{stock_name}.keras',       # Tên file để lưu
        monitor='loss',        # Theo dõi loss (hoặc 'val_loss' nếu có validation set)
        save_best_only=True,   # Chỉ lưu khi model tốt hơn checkpoint trước
        mode='min',            # Với loss nhỏ hơn là tốt hơn
        verbose=1              # In ra log khi model được lưu
    )
    sample_size = int(0.06 * len(X_train))  # Chuyển float thành integer
    # Huấn luyện model với callback
    model.fit(X_train[:sample_size], y_train[:sample_size], epochs=32, batch_size=50, verbose=2, callbacks=[checkpoint])
    
for stock_name in stock_data:
    model_name = model[stock_name]
    X_train_name = X_train[stock_name]
    y_train_name = y_train[stock_name]
    model_training(stock_name,model_name,X_train_name,y_train_name)
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.00001, saving model to best_fpt.keras
# 63/63 - 4s - 61ms/step - loss: 5.5942e-06
# Epoch 2/100
#
# Epoch 2: loss improved from 0.00001 to 0.00000, saving model to best_fpt.keras
# 63/63 - 4s - 58ms/step - loss: 4.8702e-06
# Epoch 3/100
#
# Epoch 3: loss did not improve from 0.00000
# 63/63 - 4s - 56ms/step - loss: 4.9775e-06
# Epoch 4/100
#
# Epoch 4: loss improved from 0.00000 to 0.00000, saving model to best_fpt.keras
# 63/63 - 5s - 81ms/step - loss: 4.8446e-06
# Epoch 5/100
#
# Epoch 5: loss did not improve from 0.00000
# 63/63 - 4s - 56ms/step - loss: 5.0289e-06
# Epoch 6/100
#
# Epoch 6: loss did not improve from 0.00000
# 63/63 - 4s - 65ms/step - loss: 5.0366e-06
# Epoch 7/100
#
# Epoch 7: loss did not improve from 0.00000
# 63/63 - 4s - 71ms/step - loss: 5.0826e-06
# Epoch 8/100
#
# Epoch 8: loss did not improve from 0.00000
# 63/63 - 4s - 69ms/step - loss: 4.9948e-06
# Epoch 9/100
#
# Epoch 9: loss did not improve from 0.00000
# 63/63 - 5s - 73ms/step - loss: 6.2542e-06
# Epoch 10/100
#
# Epoch 10: loss did not improve from 0.00000
# 63/63 - 4s - 60ms/step - loss: 5.4576e-06
# Epoch 11/100
#
# Epoch 11: loss did not improve from 0.00000
# 63/63 - 5s - 87ms/step - loss: 5.5101e-06
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.00000
# 63/63 - 5s - 80ms/step - loss: 4.9859e-06
# Epoch 13/100
#
# Epoch 13: loss did not improve from 0.00000
# 63/63 - 4s - 65ms/step - loss: 5.1249e-06
# Epoch 14/100
#
# Epoch 14: loss did not improve from 0.00000
# 63/63 - 5s - 82ms/step - loss: 5.2151e-06
# Epoch 15/100
#
# Epoch 15: loss improved from 0.00000 to 0.00000, saving model to best_fpt.keras
# 63/63 - 4s - 61ms/step - loss: 4.8300e-06
# Epoch 16/100
#
# Epoch 16: loss improved from 0.00000 to 0.00000, saving model to best_fpt.keras
# 63/63 - 6s - 89ms/step - loss: 4.7200e-06
# Epoch 17/100
#
# Epoch 17: loss did not improve from 0.00000
# 63/63 - 4s - 68ms/step - loss: 6.1487e-06
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.00000
# 63/63 - 5s - 77ms/step - loss: 5.1119e-06
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.00000
# 63/63 - 4s - 66ms/step - loss: 4.9448e-06
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.00000
# 63/63 - 4s - 59ms/step - loss: 5.0733e-06
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.00000
# 63/63 - 4s - 58ms/step - loss: 5.1600e-06
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.00000
# 63/63 - 5s - 79ms/step - loss: 5.3594e-06
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.00000
# 63/63 - 4s - 60ms/step - loss: 5.3368e-06
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.00000
# 63/63 - 4s - 58ms/step - loss: 5.2724e-06
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.00000
# 63/63 - 5s - 82ms/step - loss: 5.3047e-06
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.00000
# 63/63 - 5s - 78ms/step - loss: 5.2673e-06
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.00000
# 63/63 - 4s - 56ms/step - loss: 4.8798e-06
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.00000
# 63/63 - 4s - 64ms/step - loss: 5.0565e-06
# Epoch 29/100
#
# Epoch 29: loss improved from 0.00000 to 0.00000, saving model to best_fpt.keras
# 63/63 - 4s - 58ms/step - loss: 4.6556e-06
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.00000
# 63/63 - 4s - 65ms/step - loss: 5.2706e-06
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.00000
# 63/63 - 4s - 68ms/step - loss: 4.6629e-06
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.00000
# 63/63 - 4s - 68ms/step - loss: 5.3773e-06
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.00000
# 63/63 - 5s - 85ms/step - loss: 5.3459e-06
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.00000
# 63/63 - 5s - 80ms/step - loss: 5.4762e-06
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.00000
# 63/63 - 4s - 58ms/step - loss: 5.3949e-06
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.00000
# 63/63 - 4s - 62ms/step - loss: 5.5934e-06
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.00000
# 63/63 - 4s - 68ms/step - loss: 5.2670e-06
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.00000
# 63/63 - 5s - 76ms/step - loss: 5.0028e-06
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.00000
# 63/63 - 5s - 78ms/step - loss: 5.1645e-06
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.00000
# 63/63 - 5s - 75ms/step - loss: 4.8181e-06
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.00000
# 63/63 - 4s - 61ms/step - loss: 4.7847e-06
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.00000
# 63/63 - 4s - 58ms/step - loss: 5.4708e-06
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.00000
# 63/63 - 4s - 66ms/step - loss: 4.7863e-06
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.00000
# 63/63 - 5s - 82ms/step - loss: 5.0530e-06
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.00000
# 63/63 - 5s - 87ms/step - loss: 4.7460e-06
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.00000
# 63/63 - 4s - 57ms/step - loss: 4.8277e-06
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.00000
# 63/63 - 4s - 68ms/step - loss: 5.1896e-06
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.00000
# 63/63 - 5s - 82ms/step - loss: 5.0826e-06
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.00000
# 63/63 - 4s - 70ms/step - loss: 4.8970e-06
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.00000
# 63/63 - 5s - 82ms/step - loss: 5.1251e-06
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.00000
# 63/63 - 5s - 80ms/step - loss: 5.3162e-06
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.00000
# 63/63 - 4s - 63ms/step - loss: 5.2050e-06
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.00000
# 63/63 - 4s - 60ms/step - loss: 4.7976e-06
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.00000
# 63/63 - 4s - 61ms/step - loss: 4.9471e-06
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.00000
# 63/63 - 4s - 60ms/step - loss: 5.3124e-06
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.00000
# 63/63 - 4s - 58ms/step - loss: 5.0736e-06
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.00000
# 63/63 - 4s - 56ms/step - loss: 5.2332e-06
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.00000
# 63/63 - 4s - 59ms/step - loss: 6.4681e-06
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.00000
# 63/63 - 4s - 66ms/step - loss: 4.7437e-06
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.00000
# 63/63 - 5s - 78ms/step - loss: 5.3253e-06
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.00000
# 63/63 - 5s - 86ms/step - loss: 4.9241e-06
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.00000
# 63/63 - 4s - 63ms/step - loss: 5.4395e-06
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.00000
# 63/63 - 4s - 66ms/step - loss: 4.7914e-06
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.00000
# 63/63 - 4s - 61ms/step - loss: 4.7711e-06
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.00000
# 63/63 - 4s - 59ms/step - loss: 5.1267e-06
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.00000
# 63/63 - 4s - 63ms/step - loss: 5.5298e-06
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.00000
# 63/63 - 4s - 65ms/step - loss: 5.1134e-06
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.00000
# 63/63 - 5s - 76ms/step - loss: 4.8052e-06
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.00000
# 63/63 - 4s - 61ms/step - loss: 5.2869e-06
# Epoch 70/100
#
# Epoch 70: loss improved from 0.00000 to 0.00000, saving model to best_fpt.keras
# 63/63 - 4s - 61ms/step - loss: 4.6178e-06
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.00000
# 63/63 - 4s - 59ms/step - loss: 4.6467e-06
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.00000
# 63/63 - 5s - 78ms/step - loss: 4.8440e-06
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.00000
# 63/63 - 4s - 57ms/step - loss: 5.3004e-06
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.00000
# 63/63 - 4s - 58ms/step - loss: 5.0473e-06
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.00000
# 63/63 - 4s - 59ms/step - loss: 5.0069e-06
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.00000
# 63/63 - 4s - 57ms/step - loss: 5.0424e-06
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.00000
# 63/63 - 5s - 80ms/step - loss: 5.3423e-06
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.00000
# 63/63 - 4s - 57ms/step - loss: 5.1154e-06
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.00000
# 63/63 - 4s - 57ms/step - loss: 5.4314e-06
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.00000
# 63/63 - 3s - 55ms/step - loss: 4.8633e-06
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.00000
# 63/63 - 4s - 56ms/step - loss: 5.2329e-06
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.00000
# 63/63 - 4s - 59ms/step - loss: 4.9093e-06
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.00000
# 63/63 - 4s - 61ms/step - loss: 4.6644e-06
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.00000
# 63/63 - 5s - 76ms/step - loss: 5.0435e-06
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.00000
# 63/63 - 3s - 55ms/step - loss: 5.3705e-06
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00000
# 63/63 - 4s - 60ms/step - loss: 5.1683e-06
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00000
# 63/63 - 4s - 60ms/step - loss: 5.1616e-06
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.00000
# 63/63 - 4s - 58ms/step - loss: 4.8724e-06
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.00000
# 63/63 - 4s - 56ms/step - loss: 5.0889e-06
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.00000
# 63/63 - 4s - 57ms/step - loss: 5.0270e-06
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.00000
# 63/63 - 4s - 59ms/step - loss: 5.2482e-06
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00000
# 63/63 - 4s - 60ms/step - loss: 6.0605e-06
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00000
# 63/63 - 4s - 68ms/step - loss: 4.9816e-06
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.00000
# 63/63 - 4s - 68ms/step - loss: 5.2705e-06
# Epoch 95/100
#
# Epoch 95: loss improved from 0.00000 to 0.00000, saving model to best_fpt.keras
# 63/63 - 5s - 74ms/step - loss: 4.6020e-06
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00000
# 63/63 - 4s - 61ms/step - loss: 4.9167e-06
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00000
# 63/63 - 4s - 59ms/step - loss: 4.9330e-06
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00000
# 63/63 - 4s - 57ms/step - loss: 4.7004e-06
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00000
# 63/63 - 6s - 91ms/step - loss: 5.0925e-06
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.00000
# 63/63 - 4s - 58ms/step - loss: 4.9320e-06

# %%
y_train_predict = {}

def predict_data(x_train,stock_name):
    # Tải lại model tốt nhất
    best_model = load_model(f'best_{stock_name}.keras')
    y_train_predict = best_model.predict(x_train)
    y_train_predict = scaler.inverse_transform(y_train_predict)
    return y_train_predict
for stock_name in stock_data:
    X_train_name = X_train[stock_name]
    y_train_predict[stock_name] = predict_data(X_train_name,stock_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 11
#       9 for stock_name in stock_data:
#      10     X_train_name = X_train[stock_name]
# ---> 11     y_train_predict[stock_name] = predict_data(X_train_name,stock_name)
#
# Cell In[72], line 5, in predict_data(x_train, stock_name)
#       3 def predict_data(x_train,stock_name):
#       4     # Tải lại model tốt nhất
# ----> 5     best_model = load_model(f'best_model.keras')
#       6     y_train_predict = best_model.predict(x_train)
#       7     y_train_predict = scaler.inverse_transform(y_train_predict)
#
# File ~\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py:200, in load_model(filepath, custom_objects, compile, safe_mode)
#     196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
# --> 200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#     205 else:
#     206     raise ValueError(
#     207         f"File format not supported: filepath={filepath}. "
#     208         "Keras 3 only supports V3 `.keras` files and "
#    (...)
#     217         "might have a different name)."
#     218     )
#
# ValueError: File not found: filepath=best_model.keras. Please ensure the file is an accessible `.keras` zip file.

# %% [markdown]
# ## Bước 6: Sữ dụng mô hình

# %%
y_test_predict ={}

# Dự đoán giá X_test
def predict_data_test(X_test,stock_name):
    # Tải lại model tốt nhất
    best_model = load_model(f'best_{stock_name}.keras')
    y_test_predict = best_model.predict(X_test)
    y_test_predict = scaler.inverse_transform(y_test_predict)
    return y_test_predict

for stock_name in stock_data:
    X_test_name = X_test[stock_name]
    y_test_predict[stock_name] = predict_data_test(X_test_name,stock_name)
# Out:
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step
# 846/846 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step
# 783/783 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step
# 633/633 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step

# %% [markdown]
# ## Bước 7: Độ chính xác của mô hình

# %%
def plot_accuracy_chart(df,stock_name,y_train_predict,y_test_predict):
    train_size = y_train_predict.size+50
    # Copy data
    train_data = df[50:train_size].copy()
    test_data = df[train_size:].copy()
    # Gán dữ liệu
    train_data['predict'] = y_train_predict
    test_data["predict"] = y_test_predict
    
    # Lập biểu đồ so sánh
    plt.figure(figsize=(24, 8))
    plt.plot(df['Close'], label='Giá thực tế', color='red')  # Đường giá thực tế
    plt.plot(train_data["predict"], label='Giá dự đoán train', color='green')  # Đường giá dự báo train
    plt.plot(test_data["predict"], label='Giá dự đoán test', color='blue')  # Đường giá dự báo test
    plt.title(f'So sánh giá dự báo và giá thực tế của cổ phiếu {stock_name}')  # Đặt tên biểu đồ
    plt.xlabel('Thời gian')  # Đặt tên trục x
    plt.ylabel('Giá đóng cửa (VNĐ)')  # Đặt tên trục y
    plt.legend(loc='best');  # Chú thích

for stock_name in stock_data:
    df = stock_data[stock_name]
    y_train_predict_name = y_train_predict[stock_name]
    y_test_predict_name = y_test_predict[stock_name]
    plot_accuracy_chart(df,stock_name,y_train_predict_name,y_test_predict_name)
    print(y_train_predict_name.size,len(df))
# Out:
# 77884 97406
# 108243 135354
# 100207 125309
# 80972 101266

# %%
#r2
print('Độ phù hợp tập train:',r2_score(y_train,y_train_predict))
#mae
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):',mean_absolute_error(y_train,y_train_predict))
#mae
print('Phần trăm sai số tuyệt đối trung bình tập train:',mean_absolute_percentage_error(y_train,y_train_predict))

# %%
#r2
print('Độ phù hợp tập test:',r2_score(y_test,y_test_predict))
#mae
print('Sai số tuyệt đối trung bình trên tập test (VNĐ):',mean_absolute_error(y_test,y_test_predict))
#mae
print('Phần trăm sai số tuyệt đối trung bình tập test:',mean_absolute_percentage_error(y_test,y_test_predict))
